# %% [markdown]
# # Example notebook
# This is a notebook with few examples on how to read, manipulate and display images

# %% [markdown]
# # Necessary imports

# %%
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
import scipy.ndimage as nd
from napari import Viewer
from pathlib import Path

# %% [markdown]
# # Reading the image

# %%
# You might need to modify the path according to where you saved your dataset
# Note that the `Path` library will deal with OS dependant path issues
path = Path('../data/tricho.tiff')
im = imread(path)
nb_time_points = im.shape[0]

# %%
nb_time_points
# Out:
# 346

# %% [markdown]
# # Visualizing 4 time points with matplotlib

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10), subplot_kw={'aspect':1}, sharex=True, sharey=True)
axes = axes.flatten()
for i, ax in enumerate(axes):
    tp = i*(nb_time_points-1)//(len(axes)-1)
    ax.imshow(im[tp, ...], vmin=10, vmax=100)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(f'Time point {tp}')
fig.tight_layout()

# %% [markdown]
# # Visualization around laser ablation

# %%
fig, axes = plt.subplots(1, 5, figsize=(13, 5), subplot_kw={'aspect':1}, sharex=True, sharey=True)
axes = axes.flatten()
for i, ax in enumerate(axes):
    tp = 17+i
    ax.imshow(im[tp, ...], vmin=10, vmax=100)
    ax.set_xticks([])
    ax.set_yticks([])
    if tp==19:
        ax.set_title(f'Time point {tp} (ablation)')
    else:
        ax.set_title(f'Time point {tp}')
fig.tight_layout()

# %% [markdown]
# # Visualization with napari

# %%
viewer = Viewer()
viewer.add_image(im)

#napari.view_image(im)
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1924x1170+0+34 (frame: 1946x1226-11-11) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1924x1102+0+34 (frame: 1946x1158-11-11) margins: 11, 45, 11, 11 minimum size: 612x551 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=1246,1158 maxtrack=0,0)
# <Image layer 'im' at 0x1faba8b2f80>
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1920x1214+0+34 (frame: 1942x1270-11-11) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1920x974+0+34 (frame: 1942x1030-11-11) margins: 11, 45, 11, 11 minimum size: 612x607 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=1246,1270 maxtrack=0,0)

# %% [markdown]
# # Smoothing the first time-point image with a gaussian blur

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10), subplot_kw={'aspect':1})
axes = axes.flatten()
ax = axes[0]
ax.imshow(im[0, ...], vmin=10, vmax=100)
ax.set_xticks([])
ax.set_yticks([])
ax.set_title('No filter')
for sigma, ax in zip(range(1, 5), axes[1:]):
    filtered = nd.gaussian_filter(im[0, ...], sigma=sigma)
    ax.imshow(filtered, vmin=10, vmax=100)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(f'Gaussian filter, sigma={sigma}');
    fig.tight_layout()
